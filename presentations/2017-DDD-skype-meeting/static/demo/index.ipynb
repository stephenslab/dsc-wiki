# %% [markdown]
# # DSC Project overview
#
# This page displays contents of database `omega.db` generated by [this DSC](omega.html). There are two types of tables in the database:
#
# * **pipeline** tables: *add description*
# * **module** tables: *add description*

# %%
import pickle
data = pickle.load(open("omega/omega.db", 'rb'))

# %% [markdown]
# ## Pipelines

# %% [markdown]
# ### pipelines `score`
# Executed pipelines:
# * `diagonal` + `inv_diag` + `score`
# * `diagonal` + `glasso` + `score`
# * `diagonal` + `tiger` + `score`
# * `diagonal` + `clime` + `score`
# * `diagonal` + `SFAmix` + `score`
# * `diagonal` + `flash` + `score`
# * `diagonal` + `hybrid_SFAmix` + `score`
# * `diagonal` + `hybrid_flash` + `score`
# * `diagonal` + `inv_cov` + `score`
# * `toeplitz` + `inv_diag` + `score`
# * `toeplitz` + `glasso` + `score`
# * `toeplitz` + `tiger` + `score`
# * `toeplitz` + `clime` + `score`
# * `toeplitz` + `SFAmix` + `score`
# * `toeplitz` + `flash` + `score`
# * `toeplitz` + `hybrid_SFAmix` + `score`
# * `toeplitz` + `hybrid_flash` + `score`
# * `toeplitz` + `inv_cov` + `score`
# * `sparse_edors_renyi_graph` + `inv_diag` + `score`
# * `sparse_edors_renyi_graph` + `glasso` + `score`
# * `sparse_edors_renyi_graph` + `tiger` + `score`
# * `sparse_edors_renyi_graph` + `clime` + `score`
# * `sparse_edors_renyi_graph` + `SFAmix` + `score`
# * `sparse_edors_renyi_graph` + `flash` + `score`
# * `sparse_edors_renyi_graph` + `hybrid_SFAmix` + `score`
# * `sparse_edors_renyi_graph` + `hybrid_flash` + `score`
# * `sparse_edors_renyi_graph` + `inv_cov` + `score`
# * `dense_edors_renyi_graph` + `inv_diag` + `score`
# * `dense_edors_renyi_graph` + `glasso` + `score`
# * `dense_edors_renyi_graph` + `tiger` + `score`
# * `dense_edors_renyi_graph` + `clime` + `score`
# * `dense_edors_renyi_graph` + `SFAmix` + `score`
# * `dense_edors_renyi_graph` + `flash` + `score`
# * `dense_edors_renyi_graph` + `hybrid_SFAmix` + `score`
# * `dense_edors_renyi_graph` + `hybrid_flash` + `score`
# * `dense_edors_renyi_graph` + `inv_cov` + `score`
# * `band_graph` + `inv_diag` + `score`
# * `band_graph` + `glasso` + `score`
# * `band_graph` + `tiger` + `score`
# * `band_graph` + `clime` + `score`
# * `band_graph` + `SFAmix` + `score`
# * `band_graph` + `flash` + `score`
# * `band_graph` + `hybrid_SFAmix` + `score`
# * `band_graph` + `hybrid_flash` + `score`
# * `band_graph` + `inv_cov` + `score`
# * `cluster_graph` + `inv_diag` + `score`
# * `cluster_graph` + `glasso` + `score`
# * `cluster_graph` + `tiger` + `score`
# * `cluster_graph` + `clime` + `score`
# * `cluster_graph` + `SFAmix` + `score`
# * `cluster_graph` + `flash` + `score`
# * `cluster_graph` + `hybrid_SFAmix` + `score`
# * `cluster_graph` + `hybrid_flash` + `score`
# * `cluster_graph` + `inv_cov` + `score`
# * `hub_graph` + `inv_diag` + `score`
# * `hub_graph` + `glasso` + `score`
# * `hub_graph` + `tiger` + `score`
# * `hub_graph` + `clime` + `score`
# * `hub_graph` + `SFAmix` + `score`
# * `hub_graph` + `flash` + `score`
# * `hub_graph` + `hybrid_SFAmix` + `score`
# * `hub_graph` + `hybrid_flash` + `score`
# * `hub_graph` + `inv_cov` + `score`
# * `scale_free_graph` + `inv_diag` + `score`
# * `scale_free_graph` + `glasso` + `score`
# * `scale_free_graph` + `tiger` + `score`
# * `scale_free_graph` + `clime` + `score`
# * `scale_free_graph` + `SFAmix` + `score`
# * `scale_free_graph` + `flash` + `score`
# * `scale_free_graph` + `hybrid_SFAmix` + `score`
# * `scale_free_graph` + `hybrid_flash` + `score`
# * `scale_free_graph` + `inv_cov` + `score`

# %%
%preview -n data['pipeline_score']
# Out:
# Only the first 200 of the 1296 records are previewed. Use option --limit to set a new limit.
# >>> data['pipeline_score']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_1" onkeyup="filterDataFrame('1')" placeholder="Search for names..">
#     <table border="1" id="dataframe_1" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('1', 0, 'numeric')"></th>
#       <th>SFAmix_id &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('1', 1, 'alphabetic')"></th>
#       <th>SFAmix_name &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('1', 2, 'alphabetic')"></th>
#       <th>band_graph_id &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('1', 3, 'alphabetic')"></th>
# ...

# %% [markdown]
# ## Modules

# %% [markdown]
# ### module `diagonal`

# %%
%preview -n data['diagonal']
# Out:
# >>> data['diagonal']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_2" onkeyup="filterDataFrame('2')" placeholder="Search for names..">
#     <table border="1" id="dataframe_2" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('2', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('2', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('2', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('2', 3, 'alphabetic')"></th>
#       <th>seed &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('2', 4, 'numeric')"></th>
# ...

# %% [markdown]
# ### module `inv_diag`

# %%
%preview -n data['inv_diag']
# Out:
# >>> data['inv_diag']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_3" onkeyup="filterDataFrame('3')" placeholder="Search for names..">
#     <table border="1" id="dataframe_3" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('3', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('3', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('3', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('3', 3, 'alphabetic')"></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7</td>
#       <td>1</td>
#       <td>diagonal_1_inv_diag_1</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### module `loglik`

# %%
%preview -n data['loglik']
# Out:
# Only the first 200 of the 432 records are previewed. Use option --limit to set a new limit.
# >>> data['loglik']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_4" onkeyup="filterDataFrame('4')" placeholder="Search for names..">
#     <table border="1" id="dataframe_4" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('4', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('4', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('4', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('4', 3, 'alphabetic')"></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>13</td>
# ...

# %% [markdown]
# ### module `hyvarinen`

# %%
%preview -n data['hyvarinen']
# Out:
# Only the first 200 of the 432 records are previewed. Use option --limit to set a new limit.
# >>> data['hyvarinen']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_5" onkeyup="filterDataFrame('5')" placeholder="Search for names..">
#     <table border="1" id="dataframe_5" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('5', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('5', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('5', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('5', 3, 'alphabetic')"></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
# ...

# %% [markdown]
# ### module `mse`

# %%
%preview -n data['mse']
# Out:
# Only the first 200 of the 432 records are previewed. Use option --limit to set a new limit.
# >>> data['mse']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_6" onkeyup="filterDataFrame('6')" placeholder="Search for names..">
#     <table border="1" id="dataframe_6" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('6', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('6', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('6', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('6', 3, 'alphabetic')"></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>25</td>
# ...

# %% [markdown]
# ### module `glasso`

# %%
%preview -n data['glasso']
# Out:
# >>> data['glasso']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_7" onkeyup="filterDataFrame('7')" placeholder="Search for names..">
#     <table border="1" id="dataframe_7" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('7', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('7', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('7', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('7', 3, 'alphabetic')"></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>31</td>
#       <td>1</td>
#       <td>diagonal_1_glasso_1</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %% [markdown]
# ### module `tiger`

# %%
%preview -n data['tiger']
# Out:
# >>> data['tiger']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_8" onkeyup="filterDataFrame('8')" placeholder="Search for names..">
#     <table border="1" id="dataframe_8" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('8', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('8', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('8', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('8', 3, 'alphabetic')"></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>55</td>
#       <td>1</td>
#       <td>diagonal_1_tiger_1</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %% [markdown]
# ### module `clime`

# %%
%preview -n data['clime']
# Out:
# >>> data['clime']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_9" onkeyup="filterDataFrame('9')" placeholder="Search for names..">
#     <table border="1" id="dataframe_9" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('9', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('9', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('9', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('9', 3, 'alphabetic')"></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>79</td>
#       <td>1</td>
#       <td>diagonal_1_clime_1</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %% [markdown]
# ### module `SFAmix`

# %%
%preview -n data['SFAmix']
# Out:
# >>> data['SFAmix']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_10" onkeyup="filterDataFrame('10')" placeholder="Search for names..">
#     <table border="1" id="dataframe_10" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('10', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('10', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('10', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('10', 3, 'alphabetic')"></th>
#       <th>Psi_type &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('10', 4, 'alphabetic')"></th>
# ...

# %% [markdown]
# ### module `flash`

# %%
%preview -n data['flash']
# Out:
# >>> data['flash']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_11" onkeyup="filterDataFrame('11')" placeholder="Search for names..">
#     <table border="1" id="dataframe_11" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('11', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('11', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('11', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('11', 3, 'alphabetic')"></th>
#       <th>Psi_type &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('11', 4, 'alphabetic')"></th>
# ...

# %% [markdown]
# ### module `Hybrid_SFAmix`

# %%
%preview -n data['Hybrid_SFAmix']
# Out:
# >>> data['Hybrid_SFAmix']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_12" onkeyup="filterDataFrame('12')" placeholder="Search for names..">
#     <table border="1" id="dataframe_12" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('12', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('12', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('12', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('12', 3, 'alphabetic')"></th>
#       <th>Psi_type &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('12', 4, 'alphabetic')"></th>
# ...

# %% [markdown]
# ### module `Hybrid_flash`

# %%
%preview -n data['Hybrid_flash']
# Out:
# >>> data['Hybrid_flash']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_13" onkeyup="filterDataFrame('13')" placeholder="Search for names..">
#     <table border="1" id="dataframe_13" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('13', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('13', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('13', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('13', 3, 'alphabetic')"></th>
#       <th>Psi_type &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('13', 4, 'alphabetic')"></th>
# ...

# %% [markdown]
# ### module `inv_cov`

# %%
%preview -n data['inv_cov']
# Out:
# >>> data['inv_cov']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_14" onkeyup="filterDataFrame('14')" placeholder="Search for names..">
#     <table border="1" id="dataframe_14" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('14', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('14', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('14', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('14', 3, 'alphabetic')"></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>199</td>
#       <td>1</td>
#       <td>diagonal_1_inv_cov_1</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### module `toeplitz`

# %%
%preview -n data['toeplitz']
# Out:
# >>> data['toeplitz']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_15" onkeyup="filterDataFrame('15')" placeholder="Search for names..">
#     <table border="1" id="dataframe_15" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('15', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('15', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('15', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('15', 3, 'alphabetic')"></th>
#       <th>seed &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('15', 4, 'numeric')"></th>
# ...

# %% [markdown]
# ### module `sparse_edors_renyi_graph`

# %%
%preview -n data['sparse_edors_renyi_graph']
# Out:
# >>> data['sparse_edors_renyi_graph']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_16" onkeyup="filterDataFrame('16')" placeholder="Search for names..">
#     <table border="1" id="dataframe_16" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('16', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('16', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('16', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('16', 3, 'alphabetic')"></th>
#       <th>seed &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('16', 4, 'numeric')"></th>
# ...

# %% [markdown]
# ### module `dense_edors_renyi_graph`

# %%
%preview -n data['dense_edors_renyi_graph']
# Out:
# >>> data['dense_edors_renyi_graph']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_17" onkeyup="filterDataFrame('17')" placeholder="Search for names..">
#     <table border="1" id="dataframe_17" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('17', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('17', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('17', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('17', 3, 'alphabetic')"></th>
#       <th>seed &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('17', 4, 'numeric')"></th>
# ...

# %% [markdown]
# ### module `band_graph`

# %%
%preview -n data['band_graph']
# Out:
# >>> data['band_graph']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_18" onkeyup="filterDataFrame('18')" placeholder="Search for names..">
#     <table border="1" id="dataframe_18" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('18', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('18', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('18', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('18', 3, 'alphabetic')"></th>
#       <th>seed &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('18', 4, 'numeric')"></th>
# ...

# %% [markdown]
# ### module `cluster_graph`

# %%
%preview -n data['cluster_graph']
# Out:
# >>> data['cluster_graph']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_19" onkeyup="filterDataFrame('19')" placeholder="Search for names..">
#     <table border="1" id="dataframe_19" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('19', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('19', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('19', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('19', 3, 'alphabetic')"></th>
#       <th>seed &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('19', 4, 'numeric')"></th>
# ...

# %% [markdown]
# ### module `hub_graph`

# %%
%preview -n data['hub_graph']
# Out:
# >>> data['hub_graph']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_20" onkeyup="filterDataFrame('20')" placeholder="Search for names..">
#     <table border="1" id="dataframe_20" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('20', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('20', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('20', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('20', 3, 'alphabetic')"></th>
#       <th>seed &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('20', 4, 'numeric')"></th>
# ...

# %% [markdown]
# ### module `scale_free_graph`

# %%
%preview -n data['scale_free_graph']
# Out:
# >>> data['scale_free_graph']:
#     <div class='dataframe_container' style="max-height:400px">
#     <input type="text" class='dataframe_input' id="search_21" onkeyup="filterDataFrame('21')" placeholder="Search for names..">
#     <table border="1" id="dataframe_21" class="sos_dataframe dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th> &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('21', 0, 'numeric')"></th>
#       <th>ID &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('21', 1, 'numeric')"></th>
#       <th>parent &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('21', 2, 'numeric')"></th>
#       <th>FILE &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('21', 3, 'alphabetic')"></th>
#       <th>seed &nbsp; <i class="fa fa-sort" style="color:lightgray" onclick="sortDataFrame('21', 4, 'numeric')"></th>
# ...
